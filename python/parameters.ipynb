# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfJigarPandya/my-dev/blob/main/python/parameters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python feature:
# While calling a function about how to pass actual arguments to match to formal parameters
#
#
#
# Python provides partial flexibility with respect to ordering of arguments (keyword argument). At the same time you can enforce ordering importance (positional-only argument).

# %% [markdown]
# https://docs.python.org/3/library/inspect.html#inspect.Parameter.kind
#
# https://docs.python.org/3/tutorial/controlflow.html#positional-or-keyword-arguments

# %% [markdown]
# If / and * are not present in the function definition, arguments may be passed to a function by position or by keyword.
# 4.9.3.2. Positional-Only Parameters
#
# Looking at this in a bit more detail, it is possible to mark certain parameters as positional-only. If positional-only, the parameters’ order matters, and the parameters cannot be passed by keyword. Positional-only parameters are placed before a / (forward-slash). The / is used to logically separate the positional-only parameters from the rest of the parameters. If there is no / in the function definition, there are no positional-only parameters.
#  Items are passed by position, by position or keyword, or by keyword.

# %% [markdown]
# POSITIONAL_ONLY:
#
# Positional-only parameters are the ones <b>without</b> an externally usable name. Value must be supplied as a positional argument. Positional only parameters are those which appear before a / entry (if present) in a Python function definition.

# %% [markdown]
# A slash in the parameter list of a function denotes that the parameters prior to it are positional-only
#
# ```
#  divmod(a,b,/)
# ```
#
# The slash at the end of the parameter list means that both parameters are positional-only.All parameters are positional-only like c language order is fixed.

# %%
divmod(42,4)
# Out:
# (10, 2)

# %%
divmod(a=42,b=4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3130630702.py in <cell line: 0>()
# ----> 1 divmod(a=42,b=4)
#
# TypeError: divmod() takes no keyword arguments

# %% [markdown]
# Note that divmod() does NOT take any keyword arguments as there is none after slash /.

# %% [markdown]
# POSITIONAL_OR_KEYWORD
# Value may be supplied as either a keyword or positional argument (this is the standard binding behaviour for functions implemented in Python.)

# %% [markdown]
# VAR_POSITIONAL
#
# A tuple of positional arguments that aren’t bound to any other parameter. This corresponds to a *args parameter in a Python function definition.
#
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.

# %%
print("Hello World")
print("Line without backslash n",end="")
print("Line with tab",end="\t")
print("Just immediate after tab.")
# Out:
# Hello World
# Line without backslash nLine with tab	Just immediate after tab.

# %% [markdown]
# KEYWORD_ONLY
# Keyword parameters are also referred to as named parameters
#
# Value must be supplied as a keyword argument. Keyword only parameters are those which appear after a * or *args entry in a Python function definition.

# %% [markdown]
# VAR_KEYWORD
# A dict of keyword arguments that aren’t bound to any other parameter. This corresponds to a **kwargs parameter in a Python function definition.

# %% [markdown]
# Print all descriptions of arguments for a given function: i.e. print

# %%
from inspect import signature
sig = signature(print)
for param in sig.parameters.values():
    print(param.kind.description)
# Out:
# variadic positional
# keyword-only
# keyword-only
# keyword-only
# keyword-only

# %%
def list_param(*args):
  for list_member in args:
    print(list_member)
list_param(1,2,3,4,5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def dict_param(**kwargs):
  for dict_key, dict_value in kwargs.items():
    #print(str(dict_key)+":"+str(dict_value))
    print(f"{dict_key}:{dict_value}")
dict_param(id=1,name="John",age=21)
# Out:
# id:1
# name:John
# age:21
